# %%
# TensorFlow and tf.keras
import tensorflow as tf
from tensorflow import keras
# Helper libraries
import numpy as np
import matplotlib.pyplot as plt
import math

print(tf.__version__)
# Out:
# 2.18.0

# %%
# Define Constants
batch_size = 128
epochs = 100
num_classes = 10

# %%
# Download MNIST dataset.
mnist = keras.datasets.mnist
(train_images, train_labels), (test_images, test_labels) = mnist.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %%
len(train_images), len(test_images)
# Out:
# (60000, 10000)

# %%
# Normalize the input image so that each pixel value is between 0 to 1.
train_images = train_images / 255.0
test_images = test_images / 255.0

# %%
# Define the model architecture with CNN
model = keras.Sequential([
                         keras.layers.Flatten(input_shape=(28,28)),
                         # Hidden Layers
                         # keras.layers.Dense(128, activation=tf.nn.relu),
                         keras.layers.Reshape(target_shape=(28, 28, 1)),
                         keras.layers.Conv2D(filters=32, kernel_size=(3, 3), activation=tf.nn.relu),
                         keras.layers.Conv2D(filters=64, kernel_size=(3, 3), activation=tf.nn.relu),
                         keras.layers.MaxPooling2D(pool_size=(2, 2)),
                         keras.layers.Dropout(0.25),
                         keras.layers.Flatten(input_shape=(28, 28)),
                         keras.layers.Dense(128, activation=tf.nn.relu),
                         keras.layers.Dropout(0.5),

                         keras.layers.Dense(num_classes, activation='softmax')
])
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/reshaping/flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
# Save the best model as digits_model.h5
filepath = 'digits_model.h5'
modelCheckpoint = tf.keras.callbacks.ModelCheckpoint(filepath=filepath, save_best_only=True)

# %%
history = model.fit(train_images, train_labels,
                    validation_data=(test_images, test_labels),
                    epochs=epochs, batch_size=batch_size,
                    callbacks=[modelCheckpoint])
# Out:
# Epoch 1/100
# /usr/local/lib/python3.11/dist-packages/keras/src/backend/tensorflow/nn.py:708: UserWarning: "`sparse_categorical_crossentropy` received `from_logits=True`, but the `output` argument was produced by a Softmax activation and thus does not represent logits. Was this intended?
#   output, from_logits = _get_logits(
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.8561 - loss: 0.4731
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 12s 14ms/step - accuracy: 0.8563 - loss: 0.4726 - val_accuracy: 0.9832 - val_loss: 0.0512
# Epoch 2/100
# 464/469 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9722 - loss: 0.0923
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 14s 8ms/step - accuracy: 0.9722 - loss: 0.0922 - val_accuracy: 0.9864 - val_loss: 0.0408
# Epoch 3/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9822 - loss: 0.0613
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - accuracy: 0.9822 - loss: 0.0613 - val_accuracy: 0.9878 - val_loss: 0.0352
# Epoch 4/100
# 465/469 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9830 - loss: 0.0539
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - accuracy: 0.9830 - loss: 0.0539 - val_accuracy: 0.9895 - val_loss: 0.0324
# Epoch 5/100
# 468/469 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9871 - loss: 0.0408
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - accuracy: 0.9871 - loss: 0.0408 - val_accuracy: 0.9899 - val_loss: 0.0312
# Epoch 6/100
# 464/469 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9872 - loss: 0.0379
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.9872 - loss: 0.0379 - val_accuracy: 0.9911 - val_loss: 0.0280
# Epoch 7/100
# 462/469 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9879 - loss: 0.0352
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step - accuracy: 0.9879 - loss: 0.0352 - val_accuracy: 0.9913 - val_loss: 0.0274
# Epoch 8/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.9918 - loss: 0.0270 - val_accuracy: 0.9907 - val_loss: 0.0292
# Epoch 9/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - accuracy: 0.9907 - loss: 0.0285 - val_accuracy: 0.9916 - val_loss: 0.0288
# Epoch 10/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step - accuracy: 0.9926 - loss: 0.0223 - val_accuracy: 0.9918 - val_loss: 0.0278
# Epoch 11/100
# 463/469 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9932 - loss: 0.0225
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.9932 - loss: 0.0225 - val_accuracy: 0.9923 - val_loss: 0.0271
# Epoch 12/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.9922 - loss: 0.0218 - val_accuracy: 0.9917 - val_loss: 0.0301
# Epoch 13/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - accuracy: 0.9940 - loss: 0.0179 - val_accuracy: 0.9919 - val_loss: 0.0293
# Epoch 14/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - accuracy: 0.9935 - loss: 0.0172 - val_accuracy: 0.9915 - val_loss: 0.0311
# Epoch 15/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.9936 - loss: 0.0187 - val_accuracy: 0.9914 - val_loss: 0.0299
# Epoch 16/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step - accuracy: 0.9946 - loss: 0.0161 - val_accuracy: 0.9915 - val_loss: 0.0330
# Epoch 17/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.9957 - loss: 0.0125 - val_accuracy: 0.9932 - val_loss: 0.0279
# Epoch 18/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.9956 - loss: 0.0131 - val_accuracy: 0.9926 - val_loss: 0.0288
# Epoch 19/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 6s 8ms/step - accuracy: 0.9953 - loss: 0.0137 - val_accuracy: 0.9926 - val_loss: 0.0300
# Epoch 20/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.9956 - loss: 0.0132 - val_accuracy: 0.9919 - val_loss: 0.0318
# Epoch 21/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - accuracy: 0.9955 - loss: 0.0121 - val_accuracy: 0.9928 - val_loss: 0.0282
# Epoch 22/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.9956 - loss: 0.0130 - val_accuracy: 0.9933 - val_loss: 0.0302
# Epoch 23/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.9968 - loss: 0.0099 - val_accuracy: 0.9921 - val_loss: 0.0303
# Epoch 24/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.9962 - loss: 0.0103 - val_accuracy: 0.9924 - val_loss: 0.0339
# Epoch 25/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - accuracy: 0.9964 - loss: 0.0106 - val_accuracy: 0.9932 - val_loss: 0.0304
# Epoch 26/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - accuracy: 0.9964 - loss: 0.0108 - val_accuracy: 0.9929 - val_loss: 0.0287
# Epoch 27/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - accuracy: 0.9961 - loss: 0.0108 - val_accuracy: 0.9931 - val_loss: 0.0305
# Epoch 28/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - accuracy: 0.9970 - loss: 0.0099 - val_accuracy: 0.9933 - val_loss: 0.0309
# Epoch 29/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.9966 - loss: 0.0100 - val_accuracy: 0.9941 - val_loss: 0.0288
# Epoch 30/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.9971 - loss: 0.0083 - val_accuracy: 0.9929 - val_loss: 0.0294
# Epoch 31/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.9968 - loss: 0.0095 - val_accuracy: 0.9935 - val_loss: 0.0324
# Epoch 32/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.9977 - loss: 0.0072 - val_accuracy: 0.9933 - val_loss: 0.0323
# Epoch 33/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - accuracy: 0.9973 - loss: 0.0077 - val_accuracy: 0.9920 - val_loss: 0.0368
# Epoch 34/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.9970 - loss: 0.0094 - val_accuracy: 0.9924 - val_loss: 0.0372
# Epoch 35/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.9962 - loss: 0.0107 - val_accuracy: 0.9931 - val_loss: 0.0309
# Epoch 36/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.9972 - loss: 0.0078 - val_accuracy: 0.9927 - val_loss: 0.0400
# Epoch 37/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.9974 - loss: 0.0080 - val_accuracy: 0.9926 - val_loss: 0.0371
# Epoch 38/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - accuracy: 0.9976 - loss: 0.0075 - val_accuracy: 0.9935 - val_loss: 0.0354
# Epoch 39/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - accuracy: 0.9974 - loss: 0.0075 - val_accuracy: 0.9931 - val_loss: 0.0336
# Epoch 40/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - accuracy: 0.9981 - loss: 0.0060 - val_accuracy: 0.9934 - val_loss: 0.0352
# Epoch 41/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.9973 - loss: 0.0078 - val_accuracy: 0.9933 - val_loss: 0.0377
# Epoch 42/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - accuracy: 0.9972 - loss: 0.0084 - val_accuracy: 0.9934 - val_loss: 0.0329
# Epoch 43/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.9972 - loss: 0.0077 - val_accuracy: 0.9928 - val_loss: 0.0345
# Epoch 44/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.9975 - loss: 0.0070 - val_accuracy: 0.9932 - val_loss: 0.0328
# Epoch 45/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.9973 - loss: 0.0073 - val_accuracy: 0.9938 - val_loss: 0.0333
# Epoch 46/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.9978 - loss: 0.0061 - val_accuracy: 0.9933 - val_loss: 0.0343
# Epoch 47/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - accuracy: 0.9981 - loss: 0.0059 - val_accuracy: 0.9931 - val_loss: 0.0394
# Epoch 48/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - accuracy: 0.9975 - loss: 0.0075 - val_accuracy: 0.9934 - val_loss: 0.0406
# Epoch 49/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.9980 - loss: 0.0061 - val_accuracy: 0.9931 - val_loss: 0.0373
# Epoch 50/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.9980 - loss: 0.0070 - val_accuracy: 0.9941 - val_loss: 0.0302
# Epoch 51/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - accuracy: 0.9979 - loss: 0.0053 - val_accuracy: 0.9924 - val_loss: 0.0378
# Epoch 52/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.9974 - loss: 0.0065 - val_accuracy: 0.9923 - val_loss: 0.0371
# Epoch 53/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - accuracy: 0.9984 - loss: 0.0057 - val_accuracy: 0.9925 - val_loss: 0.0358
# Epoch 54/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.9981 - loss: 0.0047 - val_accuracy: 0.9926 - val_loss: 0.0418
# Epoch 55/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - accuracy: 0.9972 - loss: 0.0072 - val_accuracy: 0.9934 - val_loss: 0.0366
# Epoch 56/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - accuracy: 0.9984 - loss: 0.0045 - val_accuracy: 0.9926 - val_loss: 0.0422
# Epoch 57/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - accuracy: 0.9977 - loss: 0.0064 - val_accuracy: 0.9936 - val_loss: 0.0412
# Epoch 58/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - accuracy: 0.9985 - loss: 0.0047 - val_accuracy: 0.9935 - val_loss: 0.0364
# Epoch 59/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.9982 - loss: 0.0058 - val_accuracy: 0.9926 - val_loss: 0.0437
# Epoch 60/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - accuracy: 0.9983 - loss: 0.0052 - val_accuracy: 0.9921 - val_loss: 0.0478
# Epoch 61/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.9979 - loss: 0.0068 - val_accuracy: 0.9935 - val_loss: 0.0378
# Epoch 62/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - accuracy: 0.9984 - loss: 0.0052 - val_accuracy: 0.9936 - val_loss: 0.0420
# Epoch 63/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.9982 - loss: 0.0048 - val_accuracy: 0.9938 - val_loss: 0.0374
# Epoch 64/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - accuracy: 0.9989 - loss: 0.0039 - val_accuracy: 0.9929 - val_loss: 0.0423
# Epoch 65/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - accuracy: 0.9983 - loss: 0.0050 - val_accuracy: 0.9931 - val_loss: 0.0382
# Epoch 66/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.9982 - loss: 0.0052 - val_accuracy: 0.9921 - val_loss: 0.0480
# Epoch 67/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - accuracy: 0.9983 - loss: 0.0046 - val_accuracy: 0.9925 - val_loss: 0.0444
# Epoch 68/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - accuracy: 0.9981 - loss: 0.0058 - val_accuracy: 0.9926 - val_loss: 0.0399
# Epoch 69/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.9984 - loss: 0.0048 - val_accuracy: 0.9922 - val_loss: 0.0459
# Epoch 70/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.9981 - loss: 0.0051 - val_accuracy: 0.9934 - val_loss: 0.0394
# Epoch 71/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.9982 - loss: 0.0054 - val_accuracy: 0.9932 - val_loss: 0.0419
# Epoch 72/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - accuracy: 0.9981 - loss: 0.0055 - val_accuracy: 0.9929 - val_loss: 0.0418
# Epoch 73/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - accuracy: 0.9983 - loss: 0.0059 - val_accuracy: 0.9928 - val_loss: 0.0410
# Epoch 74/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - accuracy: 0.9984 - loss: 0.0052 - val_accuracy: 0.9927 - val_loss: 0.0478
# Epoch 75/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - accuracy: 0.9980 - loss: 0.0062 - val_accuracy: 0.9938 - val_loss: 0.0450
# Epoch 76/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.9984 - loss: 0.0045 - val_accuracy: 0.9934 - val_loss: 0.0405
# Epoch 77/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.9987 - loss: 0.0038 - val_accuracy: 0.9934 - val_loss: 0.0416
# Epoch 78/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.9991 - loss: 0.0029 - val_accuracy: 0.9932 - val_loss: 0.0433
# Epoch 79/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.9983 - loss: 0.0059 - val_accuracy: 0.9930 - val_loss: 0.0407
# Epoch 80/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.9986 - loss: 0.0036 - val_accuracy: 0.9936 - val_loss: 0.0436
# Epoch 81/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.9981 - loss: 0.0058 - val_accuracy: 0.9933 - val_loss: 0.0435
# Epoch 82/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.9990 - loss: 0.0031 - val_accuracy: 0.9930 - val_loss: 0.0479
# Epoch 83/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.9987 - loss: 0.0040 - val_accuracy: 0.9924 - val_loss: 0.0465
# Epoch 84/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.9986 - loss: 0.0044 - val_accuracy: 0.9939 - val_loss: 0.0398
# Epoch 85/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.9986 - loss: 0.0044 - val_accuracy: 0.9935 - val_loss: 0.0445
# Epoch 86/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - accuracy: 0.9983 - loss: 0.0055 - val_accuracy: 0.9937 - val_loss: 0.0392
# Epoch 87/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - accuracy: 0.9985 - loss: 0.0041 - val_accuracy: 0.9926 - val_loss: 0.0502
# Epoch 88/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.9985 - loss: 0.0042 - val_accuracy: 0.9936 - val_loss: 0.0475
# Epoch 89/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.9985 - loss: 0.0047 - val_accuracy: 0.9933 - val_loss: 0.0506
# Epoch 90/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - accuracy: 0.9979 - loss: 0.0072 - val_accuracy: 0.9926 - val_loss: 0.0479
# Epoch 91/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.9987 - loss: 0.0038 - val_accuracy: 0.9931 - val_loss: 0.0437
# Epoch 92/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.9983 - loss: 0.0052 - val_accuracy: 0.9931 - val_loss: 0.0466
# Epoch 93/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - accuracy: 0.9987 - loss: 0.0036 - val_accuracy: 0.9934 - val_loss: 0.0499
# Epoch 94/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.9984 - loss: 0.0044 - val_accuracy: 0.9933 - val_loss: 0.0521
# Epoch 95/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.9985 - loss: 0.0050 - val_accuracy: 0.9936 - val_loss: 0.0458
# Epoch 96/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.9985 - loss: 0.0047 - val_accuracy: 0.9929 - val_loss: 0.0511
# Epoch 97/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - accuracy: 0.9986 - loss: 0.0046 - val_accuracy: 0.9931 - val_loss: 0.0475
# Epoch 98/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.9987 - loss: 0.0045 - val_accuracy: 0.9921 - val_loss: 0.0513
# Epoch 99/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.9979 - loss: 0.0065 - val_accuracy: 0.9927 - val_loss: 0.0491
# Epoch 100/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.9987 - loss: 0.0041 - val_accuracy: 0.9927 - val_loss: 0.0491

# %%
# Download the digit classification model if you're using Colab
download(filepath)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-9-2616232384.py in <cell line: 0>()
#       1 # Download the digit classification model if you're using Colab
# ----> 2 download(filepath)
#
# NameError: name 'download' is not defined

# %%
# Save Model
savefile = 'saved_digits.h5'
model.save(savefile)
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ flatten (Flatten)               │ (None, 784)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ reshape (Reshape)               │ (None, 28, 28, 1)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d (Conv2D)                 │ (None, 26, 26, 32)     │           320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 24, 24, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 12, 12, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 12, 12, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_1 (Flatten)             │ (None, 9216)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 128)            │     1,179,776 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 10)             │         1,290 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 3,599,648 (13.73 MB)
#  Trainable params: 1,199,882 (4.58 MB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 2,399,766 (9.15 MB)

# %%
# !ls -al
# Out:
# total 28232
# drwxr-xr-x 1 root root     4096 Jul 15 07:05 .
# drwxr-xr-x 1 root root     4096 Jul 15 06:40 ..
# drwxr-xr-x 4 root root     4096 Jul 11 18:44 .config
# -rw-r--r-- 1 root root 14442672 Jul 15 06:54 digits_model.h5
# drwxr-xr-x 1 root root     4096 Jul 11 18:44 sample_data
# -rw-r--r-- 1 root root 14442672 Jul 15 07:05 saved_digits.h5

# %%
# Load Model
load_model = tf.keras.models.load_model(filepath)
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.

# %%
load_model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ flatten (Flatten)               │ (None, 784)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ reshape (Reshape)               │ (None, 28, 28, 1)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d (Conv2D)                 │ (None, 26, 26, 32)     │           320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 24, 24, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 12, 12, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 12, 12, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_1 (Flatten)             │ (None, 9216)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 128)            │     1,179,776 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 10)             │         1,290 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,199,884 (4.58 MB)
#  Trainable params: 1,199,882 (4.58 MB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 2 (12.00 B)

# %%
# Evaluate the model using test dataset.
test_loss, test_acc = model.evaluate(test_images, test_labels)
print('Test Accuracy: ', test_acc)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9903 - loss: 0.0574
# Test Accuracy:  0.9926999807357788

# %%
# Evaluate the load model using test dataset.
test_loss, test_acc = load_model.evaluate(test_images, test_labels)
print('Load model Test Accuracy: ', test_acc)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9901 - loss: 0.0343
# Load model Test Accuracy:  0.9922999739646912

# %%
# Helper function to display digit images
def show_sample(images, labels, sample_count=25):
  # Create a square with can fit {sample_count} images
  grid_count = math.ceil(math.ceil(math.sqrt(sample_count)))
  grid_count = min(grid_count, len(images), len(labels))

  plt.figure(figsize=(2*grid_count, 2*grid_count))
  for i in range(sample_count):
    plt.subplot(grid_count, grid_count, i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(images[i], cmap=plt.cm.gray)
    plt.xlabel(labels[i])
  plt.show()

# Helper function to display specific digit images
def show_sample_digit(images, labels, digit, sample_count=25):
  # Create a square with can fit {sample_count} images
  grid_count = math.ceil(math.ceil(math.sqrt(sample_count)))
  grid_count = min(grid_count, len(images), len(labels))

  plt.figure(figsize=(2*grid_count, 2*grid_count))
  i = 0
  digit_count = 0
  while digit_count < sample_count:
    i += 1
    if (digit == labels[i]):
      plt.subplot(grid_count, grid_count, digit_count+1)
      plt.xticks([])
      plt.yticks([])
      plt.grid(False)
      plt.imshow(images[i], cmap=plt.cm.gray)
      plt.xlabel(labels[i])
      digit_count += 1
  plt.show()

# Helper function to display specific digit images
def show_digit_image(image):
  # Draw digit image
  fig = plt.figure()
  ax = fig.add_subplot(1, 1, 1)
  # Major ticks every 20, minor ticks every 5
  major_ticks = np.arange(0, 29, 5)
  minor_ticks = np.arange(0, 29, 1)
  ax.set_xticks(major_ticks)
  ax.set_xticks(minor_ticks, minor=True)
  ax.set_yticks(major_ticks)
  ax.set_yticks(minor_ticks, minor=True)
  # And a corresponding grid
  ax.grid(which='both')
  # Or if you want different settings for the grids:
  ax.grid(which='minor', alpha=0.2)
  ax.grid(which='major', alpha=0.5)
  ax.imshow(image, cmap=plt.cm.binary)

  plt.show()

# Download the digit classification model if you're using Colab,
# or print the model's local path if you're not using Colab.
def download(path):
    try:
        from google.colab import files
        files.download(path)
    except ImportError:
        import os
        print('Error dowbload:', os.path.join(os,getcwd(), path))

# %%
# Show the first 25 images in the training dataset.
show_sample(test_images, ['Label: %s' % label for label in test_labels])

# %%
# Show digit 7 the first 25 images in the training dataset.
show_sample_digit(train_images, train_labels, 7)

# %%
# Evaluate the model using test dataset. - Show performance

fig, loss_ax = plt.subplots()
fig, acc_ax = plt.subplots()

loss_ax.plot(history.history['loss'], 'ro', label='train_loss')
loss_ax.plot(history.history['val_loss'], 'r:', label='validation_loss')
loss_ax.set_xlabel('epoch')
loss_ax.set_ylabel('loss')
loss_ax.legend(loc='upper left')

acc_ax.plot(history.history['accuracy'], 'bo', label='train_accuracy')
acc_ax.plot(history.history['val_accuracy'], 'b:', label='validation_accuracy')
acc_ax.set_xlabel('epoch')
acc_ax.set_ylabel('accuracy')

acc_ax.legend(loc='upper left')

plt.show()

# %%
# Predict the labels of digit images in our test dataset.
predictions = model.predict(test_images)

# Then plot the first 25 test images and their predicted labels.
show_sample(test_images, ['Predicted: %d ' % np.argmax(result) for result in predictions])

# %%
Digit = 8226 #@param {type:"slider", min:1, max:10000, step:1}
selected_digit = Digit - 1

result = predictions[selected_digit]
result_number = np.argmax(result)
print('Number is %2d' % result_number)

show_digit_image(test_images[selected_digit])
# Out:
# Number is  2
